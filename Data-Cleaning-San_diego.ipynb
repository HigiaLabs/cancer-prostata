# %%
# Data referência https://data.sandiegocounty.gov/Health/Prostate-Cancer/gpsr-f4mg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
prostate_cancer =  pd.read_csv('DataPrincipal/Prostate_Cancer.csv')

# %%
prostate_cancer
# Out:
#             CONDITION                OUTCOME  Year               Geography  \
# 0     Prostate Cancer                  Death  2017        San Diego County
# 1     Prostate Cancer                  Death  2017          Central Region
# 2     Prostate Cancer                  Death  2017       Central San Diego
# 3     Prostate Cancer                  Death  2017                Mid-City
# 4     Prostate Cancer                  Death  2017  Southeastern San Diego
# ...               ...                    ...   ...                     ...
# 3061  Prostate Cancer  SNF/Intermediate Care  2011      City of San Marcos
# 3062  Prostate Cancer  SNF/Intermediate Care  2011          City of Santee
# 3063  Prostate Cancer  SNF/Intermediate Care  2011    City of Solana Beach
# 3064  Prostate Cancer  SNF/Intermediate Care  2011           City of Vista
# 3065  Prostate Cancer  SNF/Intermediate Care  2011          Unincorporated
#
#         GeoType                 GeoName  GeoID   Region  \
# 0           NaN        SAN DIEGO COUNTY     99      NaN
# 1        Region                 CENTRAL      3  CENTRAL
# 2           SRA       CENTRAL SAN DIEGO      1  CENTRAL
# 3           SRA                MID-CITY      6  CENTRAL
# 4           SRA  SOUTHEASTERN SAN DIEGO      5  CENTRAL
# ...         ...                     ...    ...      ...
# 3061  Municipal              SAN MARCOS     15      NaN
# 3062  Municipal                  SANTEE     16      NaN
# 3063  Municipal            SOLANA BEACH     17      NaN
# 3064  Municipal                   VISTA     18      NaN
# 3065  Municipal          UNINCORPORATED     19      NaN
#
#                       District  Total_Male  ...  Other_notAIAN_Age0_14_Male  \
# 0                          NaN       310.0  ...                         NaN
# 1                          NaN        32.0  ...                         NaN
# 2     Supervisorial District 4        14.0  ...                         NaN
# 3     Supervisorial District 4        10.0  ...                         NaN
# 4     Supervisorial District 4        10.0  ...                         NaN
# ...                        ...         ...  ...                         ...
# 3061                       NaN         NaN  ...                         NaN
# 3062                       NaN         NaN  ...                         NaN
# 3063                       NaN         NaN  ...                         NaN
# 3064                       NaN         NaN  ...                         NaN
# 3065                       NaN         NaN  ...                         NaN
#
#       Other_notAIAN_Age0_14_MaleRate  Other_notAIAN_Age15_24_Male  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# ...                              ...                          ...
# 3061                             NaN                          NaN
# 3062                             NaN                          NaN
# 3063                             NaN                          NaN
# 3064                             NaN                          NaN
# 3065                             NaN                          NaN
#
#       Other_notAIAN_Age15_24_MaleRate  Other_notAIAN_Age25_44_Male  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 3061                              NaN                          NaN
# 3062                              NaN                          NaN
# 3063                              NaN                          NaN
# 3064                              NaN                          NaN
# 3065                              NaN                          NaN
#
#       Other_notAIAN_Age25_44_MaleRate  Other_notAIAN_Age45_64_Male  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 3061                              NaN                          NaN
# 3062                              NaN                          NaN
# 3063                              NaN                          NaN
# 3064                              NaN                          NaN
# 3065                              NaN                          NaN
#
#       Other_notAIAN_Age45_64_MaleRate  Other_notAIAN_Age65Plus_Male  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 3061                              NaN                           NaN
# 3062                              NaN                           NaN
# 3063                              NaN                           NaN
# 3064                              NaN                           NaN
# 3065                              NaN                           NaN
#
#       Other_notAIAN_Age65Plus_MaleRate
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3061                               NaN
# 3062                               NaN
# 3063                               NaN
# 3064                               NaN
# 3065                               NaN
#
# [3066 rows x 94 columns]

# %%
prostate_cancer_principal =  prostate_cancer[['CONDITION', 'OUTCOME', 'Year', 'Geography', 'GeoType','GeoName', 'GeoID', 'Region', 'District', 'Total_Male' ]]
prostate_cancer_principal.to_csv('prostate_cancer_principal.csv')

# %%
counting_age_prostate_cancer = prostate_cancer.iloc[:, 12:]
counting_age_prostate_cancer.head(5)
# Out:
#    Age0_14_Male  Age0_14_MaleRate  Age15_24_Male  Age15_24_MaleRate  \
# 0           NaN               NaN            NaN                NaN
# 1           NaN               NaN            NaN                NaN
# 2           NaN               NaN            NaN                NaN
# 3           NaN               NaN            NaN                NaN
# 4           NaN               NaN            NaN                NaN
#
#    Age25_44_Male  Age25_44_MaleRate  Age45_64_Male  Age45_64_MaleRate  \
# 0            NaN                NaN           24.0               5.98
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#    Age65Plus_Male  Age65Plus_MaleRate  ...  Other_notAIAN_Age0_14_Male  \
# 0           286.0              139.02  ...                         NaN
# 1            29.0              107.67  ...                         NaN
# 2            13.0              109.62  ...                         NaN
# 3             8.0               95.53  ...                         NaN
# 4             9.0              128.11  ...                         NaN
#
#    Other_notAIAN_Age0_14_MaleRate  Other_notAIAN_Age15_24_Male  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#    Other_notAIAN_Age15_24_MaleRate  Other_notAIAN_Age25_44_Male  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#    Other_notAIAN_Age25_44_MaleRate  Other_notAIAN_Age45_64_Male  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#    Other_notAIAN_Age45_64_MaleRate  Other_notAIAN_Age65Plus_Male  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#    Other_notAIAN_Age65Plus_MaleRate
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 82 columns]

# %%
counting_age_prostate_cancer_without_values_columns_NAN =  counting_age_prostate_cancer[counting_age_prostate_cancer.columns[~counting_age_prostate_cancer.isnull().all()]]
counting_age_prostate_cancer_without_values_columns_NAN
# Out:
#       Age25_44_Male  Age25_44_MaleRate  Age45_64_Male  Age45_64_MaleRate  \
# 0               NaN                NaN           24.0               5.98
# 1               NaN                NaN            NaN                NaN
# 2               NaN                NaN            NaN                NaN
# 3               NaN                NaN            NaN                NaN
# 4               NaN                NaN            NaN                NaN
# ...             ...                ...            ...                ...
# 3061            NaN                NaN            NaN                NaN
# 3062            NaN                NaN            NaN                NaN
# 3063            NaN                NaN            NaN                NaN
# 3064            NaN                NaN            NaN                NaN
# 3065            NaN                NaN            NaN                NaN
#
#       Age65Plus_Male  Age65Plus_MaleRate  White_Total_Male  \
# 0              286.0              139.02             234.0
# 1               29.0              107.67              20.0
# 2               13.0              109.62              11.0
# 3                8.0               95.53               9.0
# 4                9.0              128.11               NaN
# ...              ...                 ...               ...
# 3061             NaN                 NaN               NaN
# 3062             NaN                 NaN               NaN
# 3063             NaN                 NaN               NaN
# 3064             NaN                 NaN               NaN
# 3065             NaN                 NaN               NaN
#
#       White_Total_MaleRate  White_Age25_44_Male  White_Age25_44_MaleRate  ...  \
# 0                    29.82                  NaN                      NaN  ...
# 1                    22.64                  NaN                      NaN  ...
# 2                    20.65                  NaN                      NaN  ...
# 3                    32.66                  NaN                      NaN  ...
# 4                      NaN                  NaN                      NaN  ...
# ...                    ...                  ...                      ...  ...
# 3061                   NaN                  NaN                      NaN  ...
# 3062                   NaN                  NaN                      NaN  ...
# 3063                   NaN                  NaN                      NaN  ...
# 3064                   NaN                  NaN                      NaN  ...
# 3065                   NaN                  NaN                      NaN  ...
#
#       API_Age45_64_Male  API_Age45_64_MaleRate  API_Age65Plus_Male  \
# 0                   NaN                    NaN                19.0
# 1                   NaN                    NaN                 NaN
# 2                   NaN                    NaN                 NaN
# 3                   NaN                    NaN                 NaN
# 4                   NaN                    NaN                 NaN
# ...                 ...                    ...                 ...
# 3061                NaN                    NaN                 NaN
# 3062                NaN                    NaN                 NaN
# 3063                NaN                    NaN                 NaN
# 3064                NaN                    NaN                 NaN
# 3065                NaN                    NaN                 NaN
#
#       API_Age65Plus_MaleRate  Other_notAIAN_Total_Male  \
# 0                      86.32                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 3061                     NaN                       NaN
# 3062                     NaN                       NaN
# 3063                     NaN                       NaN
# 3064                     NaN                       NaN
# 3065                     NaN                       NaN
#
#       Other_notAIAN_Total_MaleRate  Other_notAIAN_Age45_64_Male  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 3061                           NaN                          NaN
# 3062                           NaN                          NaN
# 3063                           NaN                          NaN
# 3064                           NaN                          NaN
# 3065                           NaN                          NaN
#
#       Other_notAIAN_Age45_64_MaleRate  Other_notAIAN_Age65Plus_Male  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 3061                              NaN                           NaN
# 3062                              NaN                           NaN
# 3063                              NaN                           NaN
# 3064                              NaN                           NaN
# 3065                              NaN                           NaN
#
#       Other_notAIAN_Age65Plus_MaleRate
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3061                               NaN
# 3062                               NaN
# 3063                               NaN
# 3064                               NaN
# 3065                               NaN
#
# [3066 rows x 38 columns]

# %%
counting_age_prostate_cancer.columns.unique()
# Out:
# Index(['Age0_14_Male', 'Age0_14_MaleRate', 'Age15_24_Male',
#        'Age15_24_MaleRate', 'Age25_44_Male', 'Age25_44_MaleRate',
#        'Age45_64_Male', 'Age45_64_MaleRate', 'Age65Plus_Male',
#        'Age65Plus_MaleRate', 'White_Total_Male', 'White_Total_MaleRate',
#        'White_Age0_14_Male', 'White_Age0_14_MaleRate', 'White_Age15_24_Male',
#        'White_Age15_24_MaleRate', 'White_Age25_44_Male',
#        'White_Age25_44_MaleRate', 'White_Age45_64_Male',
#        'White_Age45_64_MaleRate', 'White_Age65Plus_Male',
#        'White_Age65Plus_MaleRate', 'Black_Total_Male', 'Black_Total_MaleRate',
#        'Black_Age0_14_Male', 'Black_Age0_14_MaleRate', 'Black_Age15_24_Male',
#        'Black_Age15_24_MaleRate', 'Black_Age25_44_Male',
#        'Black_Age25_44_MaleRate', 'Black_Age45_64_Male',
#        'Black_Age45_64_MaleRate', 'Black_Age65Plus_Male',
#        'Black_Age65Plus_MaleRate', 'Hispanic_Total_Male',
#        'Hispanic_Total_MaleRate', 'Hispanic_Age0_14_Male',
#        'Hispanic_Age0_14_MaleRate', 'Hispanic_Age15_24_Male',
#        'Hispanic_Age15_24_MaleRate', 'Hispanic_Age25_44_Male',
#        'Hispanic_Age25_44_MaleRate', 'Hispanic_Age45_64_Male',
#        'Hispanic_Age45_64_MaleRate', 'Hispanic_Age65Plus_Male',
#        'Hispanic_Age65Plus_MaleRate', 'API_Total_Male', 'API_Total_MaleRate',
#        'API_Age0_14_Male', 'API_Age0_14_MaleRate', 'API_Age15_24_Male',
#        'API_Age15_24_MaleRate', 'API_Age25_44_Male', 'API_Age25_44_MaleRate',
#        'API_Age45_64_Male', 'API_Age45_64_MaleRate', 'API_Age65Plus_Male',
#        'API_Age65Plus_MaleRate', 'AIAN_Total_Male', 'AIAN_Total_MaleRate',
#        'AIAN_Age0_14_Male', 'AIAN_Age0_14_MaleRate', 'AIAN_Age15_24_Male',
#        'AIAN_Age15_24_MaleRate', 'AIAN_Age25_44_Male',
#        'AIAN_Age25_44_MaleRate', 'AIAN_Age45_64_Male',
#        'AIAN_Age45_64_MaleRate', 'AIAN_Age65Plus_Male',
#        'AIAN_Age65Plus_MaleRate', 'Other_notAIAN_Total_Male',
#        'Other_notAIAN_Total_MaleRate', 'Other_notAIAN_Age0_14_Male',
#        'Other_notAIAN_Age0_14_MaleRate', 'Other_notAIAN_Age15_24_Male',
#        'Other_notAIAN_Age15_24_MaleRate', 'Other_notAIAN_Age25_44_Male',
#        'Other_notAIAN_Age25_44_MaleRate', 'Other_notAIAN_Age45_64_Male',
#        'Other_notAIAN_Age45_64_MaleRate', 'Other_notAIAN_Age65Plus_Male',
#        'Other_notAIAN_Age65Plus_MaleRate'],
#       dtype='object')

# %%
male = counting_age_prostate_cancer.iloc[:,0:10]
male = male[sorted(male.columns)]
male.head(3)

# %%
male_plot = counting_age_prostate_cancer[['White_Age0_14_Male','White_Age15_24_Male','White_Age25_44_Male' ,'White_Age45_64_Male', 'White_Age65Plus_Male', 'White_Total_Male']]
male_plot.to_csv('people/male.csv')

male_plot_rate = counting_age_prostate_cancer[['White_Age0_14_MaleRate','White_Age15_24_MaleRate','White_Age25_44_MaleRate' ,'White_Age45_64_MaleRate', 'White_Age65Plus_MaleRate', 'White_Total_MaleRate']]
male_plot_rate.to_csv('people/male_rate.csv')

# %%
white_male = counting_age_prostate_cancer[['White_Age0_14_Male' , 'White_Age15_24_Male' , 'White_Age25_44_Male',  'White_Age45_64_Male' , 'White_Age65Plus_Male']]
# white_male.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)
white_male.to_csv('people/white_male.csv')

white_male_rate = counting_age_prostate_cancer[['White_Age0_14_MaleRate' , 'White_Age15_24_MaleRate' , 'White_Age25_44_MaleRate',  'White_Age45_64_MaleRate' , 'White_Age65Plus_MaleRate']]
# white_male_rate.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)
white_male_rate.to_csv('people/white_male_rate.csv')

# %%
black_male_plot = counting_age_prostate_cancer[['Black_Age0_14_Male', 'Black_Age15_24_Male', 'Black_Age25_44_Male' , 'Black_Age45_64_Male', 'Black_Age65Plus_Male', 'Black_Total_Male']]
black_male_plot.to_csv('people/black.csv')

black_male_plot_rate = counting_age_prostate_cancer[['Black_Age0_14_MaleRate', 'Black_Age15_24_MaleRate', 'Black_Age25_44_MaleRate' , 'Black_Age45_64_MaleRate', 'Black_Age65Plus_MaleRate','Black_Total_MaleRate']]
black_male_plot_rate.to_csv('people/black_rate.csv')
# black_male_plot.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)

# %%
hispanic_plot =  counting_age_prostate_cancer[['Hispanic_Age0_14_Male' , 'Hispanic_Age15_24_Male' , 'Hispanic_Age25_44_Male' , 'Hispanic_Age45_64_Male', 'Hispanic_Age65Plus_Male']]
hispanic_plot.to_csv('people/hispanic.csv')
# hispanic_plot.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)

hispanic_plot_rate =  counting_age_prostate_cancer[['Hispanic_Age0_14_MaleRate' , 'Hispanic_Age15_24_MaleRate' , 'Hispanic_Age25_44_MaleRate' , 'Hispanic_Age45_64_MaleRate', 'Hispanic_Age65Plus_MaleRate']]
hispanic_plot_rate.to_csv('people/hispanic_rate.csv')

# %%
api_plot =  counting_age_prostate_cancer[['API_Age0_14_Male' , 'API_Age15_24_Male' , 'API_Age25_44_Male' , 'API_Age45_64_Male', 'API_Age65Plus_Male' , 'API_Total_Male']]
api_plot.to_csv('people/api.csv')
# hispanic_plot.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)

api_plot_rate =  counting_age_prostate_cancer[['Hispanic_Age0_14_MaleRate' , 'Hispanic_Age15_24_MaleRate' , 'Hispanic_Age25_44_MaleRate' , 'Hispanic_Age45_64_MaleRate', 'Hispanic_Age65Plus_MaleRate']]
api_plot_rate.to_csv('people/api_rate.csv')

# %%
aian_plot =  counting_age_prostate_cancer[['AIAN_Age0_14_Male' , 'AIAN_Age15_24_Male' , 'AIAN_Age25_44_Male' , 'AIAN_Age45_64_Male', 'AIAN_Age65Plus_Male' , 'AIAN_Total_Male']]
aian_plot.to_csv('people/aian.csv')
# hispanic_plot.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)

aian_plot_rate =  counting_age_prostate_cancer[['AIAN_Age0_14_MaleRate' , 'AIAN_Age15_24_MaleRate' , 'AIAN_Age25_44_MaleRate' , 'AIAN_Age45_64_MaleRate', 'AIAN_Age65Plus_MaleRate', 'AIAN_Total_MaleRate']]
aian_plot_rate.to_csv('people/aian_rate.csv')

# %%
other_notaian_plot =  counting_age_prostate_cancer[['Other_notAIAN_Age0_14_Male' , 'Other_notAIAN_Age15_24_Male' , 'Other_notAIAN_Age25_44_Male' , 'Other_notAIAN_Age45_64_Male', 'Other_notAIAN_Age65Plus_Male' , 'Other_notAIAN_Total_Male']]
other_notaian_plot.to_csv('people/other_notaian.csv')
# hispanic_plot.sum().plot.bar(figsize=(20,12), rot=1,stacked=True)

other_notaian_plot_rate =  counting_age_prostate_cancer[['Other_notAIAN_Age0_14_MaleRate' , 'Other_notAIAN_Age15_24_MaleRate' , 'Other_notAIAN_Age25_44_MaleRate' , 'Other_notAIAN_Age45_64_MaleRate', 'Other_notAIAN_Age65Plus_MaleRate' , 'Other_notAIAN_Total_MaleRate']]
other_notaian_plot_rate.to_csv('people/other_notaian_rate.csv')

# %%
other_male =  counting_age_prostate_cancer.iloc[:, 71:]
other_male.head(3)
# Out:
#    Other_notAIAN_Total_MaleRate  Other_notAIAN_Age0_14_Male  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
#
#    Other_notAIAN_Age0_14_MaleRate  Other_notAIAN_Age15_24_Male  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#    Other_notAIAN_Age15_24_MaleRate  Other_notAIAN_Age25_44_Male  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#    Other_notAIAN_Age25_44_MaleRate  Other_notAIAN_Age45_64_Male  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#    Other_notAIAN_Age45_64_MaleRate  Other_notAIAN_Age65Plus_Male  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
#
#    Other_notAIAN_Age65Plus_MaleRate
# 0                               NaN
# 1                               NaN
# 2                               NaN

# %%
black_male =  counting_age_prostate_cancer.iloc[:,23:34]
black_male.head(3)
# black_male.sum().plot.bar(figsize=(20,12))
# Out:
#    Black_Total_MaleRate  Black_Age0_14_Male  Black_Age0_14_MaleRate  \
# 0                 22.54                 NaN                     NaN
# 1                   NaN                 NaN                     NaN
# 2                   NaN                 NaN                     NaN
#
#    Black_Age15_24_Male  Black_Age15_24_MaleRate  Black_Age25_44_Male  \
# 0                  NaN                      NaN                  NaN
# 1                  NaN                      NaN                  NaN
# 2                  NaN                      NaN                  NaN
#
#    Black_Age25_44_MaleRate  Black_Age45_64_Male  Black_Age45_64_MaleRate  \
# 0                      NaN                  NaN                      NaN
# 1                      NaN                  NaN                      NaN
# 2                      NaN                  NaN                      NaN
#
#    Black_Age65Plus_Male  Black_Age65Plus_MaleRate
# 0                  15.0                    214.75
# 1                   NaN                       NaN
# 2                   NaN                       NaN

# %%
hispanic =counting_age_prostate_cancer.iloc[:,34:46]
hispanic.head(3)

# %%
api_male = counting_age_prostate_cancer.iloc[:, 47:58]
api_male.head(3)
# Out:
#    API_Total_MaleRate  API_Age0_14_Male  API_Age0_14_MaleRate  \
# 0               10.65               NaN                   NaN
# 1                 NaN               NaN                   NaN
# 2                 NaN               NaN                   NaN
#
#    API_Age15_24_Male  API_Age15_24_MaleRate  API_Age25_44_Male  \
# 0                NaN                    NaN                NaN
# 1                NaN                    NaN                NaN
# 2                NaN                    NaN                NaN
#
#    API_Age25_44_MaleRate  API_Age45_64_Male  API_Age45_64_MaleRate  \
# 0                    NaN                NaN                    NaN
# 1                    NaN                NaN                    NaN
# 2                    NaN                NaN                    NaN
#
#    API_Age65Plus_Male  API_Age65Plus_MaleRate
# 0                19.0                   86.32
# 1                 NaN                     NaN
# 2                 NaN                     NaN

# %%
aian_male =  counting_age_prostate_cancer.iloc[:, 58:70]
aian_male.head(3)
# Out:
#    AIAN_Total_Male  AIAN_Total_MaleRate  AIAN_Age0_14_Male  \
# 0              NaN                  NaN                NaN
# 1              NaN                  NaN                NaN
# 2              NaN                  NaN                NaN
#
#    AIAN_Age0_14_MaleRate  AIAN_Age15_24_Male  AIAN_Age15_24_MaleRate  \
# 0                    NaN                 NaN                     NaN
# 1                    NaN                 NaN                     NaN
# 2                    NaN                 NaN                     NaN
#
#    AIAN_Age25_44_Male  AIAN_Age25_44_MaleRate  AIAN_Age45_64_Male  \
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2                 NaN                     NaN                 NaN
#
#    AIAN_Age45_64_MaleRate  AIAN_Age65Plus_Male  AIAN_Age65Plus_MaleRate
# 0                     NaN                  NaN                      NaN
# 1                     NaN                  NaN                      NaN
# 2                     NaN                  NaN                      NaN

# %%
names_dataframe =  list()
for people in types_of_people:
    names_dataframe.append(f'dataframe_type_people_{people}')

# %%
for coluna in counting_age_prostate_cancer_without_valuecolumnsolumns_NAN.columns.unique():
    counting_age_prostate_cancer_without_values_columns_NAN.groupby(coluna)[coluna].sum().plot.bar(figsize=(20,12),label=coluna)

# %%
death =  prostate_cancer_principal[prostate_cancer_principal['CONDITION'] ==  'Death']

# %%
outcome  = prostate_cancer_principal.OUTCOME.unique()
outcome
# Out:
# array(['Death', 'ED Discharge', 'Hospitalization', 'In-Patient Treatment',
#        'Physical Rehabilitation', 'SNF/Intermediate Care'], dtype=object)

# %%
# About San Diego
#https://mmasc.org/167/San-Diego-County-Region
geography =  prostate_cancer_principal.Geography.unique()
geography
# Out:
# array(['San Diego County', 'Central Region', 'Central San Diego',
#        'Mid-City', 'Southeastern San Diego', 'East Region', 'Alpine',
#        'El Cajon', 'Harbison Crest', 'Harbison Crest-El Cajon', 'Jamul',
#        'La Mesa', 'Laguna-Pine Valley', 'Lakeside', 'Lemon Grove',
#        'Mountain Empire', 'Santee', 'Spring Valley',
#        'North Central Region', 'Coastal', 'Del Mar-Mira Mesa',
#        'Elliott-Navajo', 'Kearny Mesa', 'Miramar', 'Peninsula',
#        'University', 'North Coastal Region', 'Carlsbad', 'Oceanside',
#        'Pendleton', 'San Dieguito', 'Vista', 'North Inland Region',
#        'Anza-Borrego Springs', 'Escondido', 'Fallbrook',
#        'North San Diego', 'Palomar-Julian', 'Pauma', 'Poway', 'Ramona',
#        'San Marcos', 'Valley Center', 'South Region', 'Chula Vista',
#        'Coronado', 'National City', 'South Bay', 'Sweetwater',
#        'Supervisorial District 1', 'Supervisorial District 2',
#        'Supervisorial District 3', 'Supervisorial District 4',
#        'Supervisorial District 5', 'City of Carlsbad',
#        'City of Chula Vista', 'City of Coronado', 'City of Del Mar',
#        'City of El Cajon', 'City of Encinitas', 'City of Escondido',
#        'City of Imperial Beach', 'City of La Mesa', 'City of Lemon Grove',
#        'City of National City', 'City of Oceanside', 'City of Poway',
#        'City of San Diego', 'City of San Marcos', 'City of Santee',
#        'City of Solana Beach', 'City of Vista', 'Unincorporated'],
#       dtype=object)

# %%
death  = prostate_cancer_principal[prostate_cancer_principal['OUTCOME'] == 'Death']
death.head(5)
# Out:
#          CONDITION OUTCOME  Year               Geography GeoType  \
# 0  Prostate Cancer   Death  2017        San Diego County     NaN
# 1  Prostate Cancer   Death  2017          Central Region  Region
# 2  Prostate Cancer   Death  2017       Central San Diego     SRA
# 3  Prostate Cancer   Death  2017                Mid-City     SRA
# 4  Prostate Cancer   Death  2017  Southeastern San Diego     SRA
#
#                   GeoName  GeoID   Region                  District  \
# 0        SAN DIEGO COUNTY     99      NaN                       NaN
# 1                 CENTRAL      3  CENTRAL                       NaN
# 2       CENTRAL SAN DIEGO      1  CENTRAL  Supervisorial District 4
# 3                MID-CITY      6  CENTRAL  Supervisorial District 4
# 4  SOUTHEASTERN SAN DIEGO      5  CENTRAL  Supervisorial District 4
#
#    Total_Male
# 0       310.0
# 1        32.0
# 2        14.0
# 3        10.0
# 4        10.0

# %%
death.plot(x='Year', y ='Total_Male', figsize=(20,12))
